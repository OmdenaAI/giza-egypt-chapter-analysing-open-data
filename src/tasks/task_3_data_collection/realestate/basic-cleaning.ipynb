# %%
# !python3 merge.py >& /dev/null

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('./merged.csv', low_memory=False)

# %%
df
# Out:
#           price                       location  \
# 0       1250000               Nasr City، Cairo
# 1       1260000                Madinaty, Cairo
# 2       1260000  New Cairo - El Tagamoa، Cairo
# 3       1250000        New Capital City، Cairo
# 4       1250000  New Cairo - El Tagamoa، Cairo
# ...         ...                            ...
# 172256  2436525  New Cairo - El Tagamoa، Cairo
# 172257  2440000        New Capital City, Cairo
# 172258  2437500  New Cairo - El Tagamoa، Cairo
# 172259  2440000        New Capital City, Cairo
# 172260  2433000        New Capital City, Cairo
#
#                                                     title bedrooms    area  \
# 0                       شقه ١٥٤م بعمارات العبور صلاح سالم        3     154
# 1                 شقه للبيع 96م فيو وايد جاردن بمليون 260        2      96
# 2       شقتك في قلب التجمع الخامس في بيت الوطن دقيقة م...        3     175
# 3                  شقة 160م بكومباوند بيرلا سموحة الجديدة        3     160
# 4           شقه للبيع 125م بالنرجس عمارات الترا سوبر لوكس        2     125
# ...                                                   ...      ...     ...
# 172256  شقه للبيع 221م بتقسيط علي 10سنين في زا ايكون_T...        4     221
# 172257           شقة بالعاصمة الادارية بأروع كمبوند فينشى        3     181
# 172258  استلم فووورا اخرر شقة بميدتاون امام الجامعة ال...        4     250
# 172259  امتلك فى العاصمة شقة ارضى بمقدم 10% فى كمبوند ...        3     215
# 172260                          العاصمه الاداريه ديجويا 3        3  16,800
#
#          level bathrooms furnished       type  delivery_date  ...  \
# 0            3         2       NaN  Apartment            NaN  ...
# 1            5         2       NaN  Apartment  Ready to move  ...
# 2            2         2       NaN  Apartment            NaN  ...
# 3            3         2       NaN  Apartment            NaN  ...
# 4            2         1        No  Apartment  Ready to move  ...
# ...        ...       ...       ...        ...            ...  ...
# 172256       1         3       NaN  Apartment            NaN  ...
# 172257       5         3        No  Apartment           2024  ...
# 172258  Ground         3        No  Apartment            NaN  ...
# 172259  Ground         2        No  Apartment            NaN  ...
# 172260       5         2        No  Apartment           2023  ...
#
#        down_payment       payment_option compound  delivery_term views  \
# 0               NaN                  NaN      NaN            NaN   522
# 1               NaN                 Cash      NaN       Finished   177
# 2               NaN          Installment      NaN  Semi Finished   105
# 3               NaN                 Cash      NaN            NaN   101
# 4               NaN                 Cash      NaN            NaN   424
# ...             ...                  ...      ...            ...   ...
# 172256      487,307  Cash or Installment      NaN            NaN   213
# 172257    1,340,000          Installment    Vinci            NaN   202
# 172258          NaN  Cash or Installment      NaN            NaN   385
# 172259          NaN  Cash or Installment      NaN            NaN   188
# 172260      243,300          Installment  De Joya  Semi Finished   155
#
#                                               description        date  \
# 0       شقة ١٥٤ م بحري عمارات العبور علي صلاح سالم- تش...  01/02/2022
# 1       شقه للبيع 96م فيو وايد جاردن\nبالمرحله الحاديه...  08/02/2022
# 2       بيتك الجديد في قلب التجمع الخامس في بيت الوطن ...  07/02/2022
# 3       شقة بكومباوند بيرلا ١ سموحة الجديدة امام المدا...  03/02/2022
# 4       شقه بالنرجس عمارات 125م \nالترا سوبر لوكس دور ...  02/02/2022
# ...                                                   ...         ...
# 172256  شقه للبيع 221م  بتقسيط علي 10سنين في زا ايكون ...  28/11/2021
# 172257  شقة بأروع كومبوند بالعاصمة الادارية ..R7 شركة ...  20/11/2021
# 172258  استلم فووورا شقتك امام الجامعه الامريكيه مباشر...  20/11/2021
# 172259  اسـتـثـمر بنجاح فى العاصمة الادارية وعيش حباة ...  18/11/2021
# 172260  DEJOYA 3 انتهز الفرصه موقع متميز ومساحه متميزه...  17/11/2021
#
#                 owner_name                                   owner_id  \
# 0                     wael  https://www.olx.com.eg/en/ads/user/6T42Q/
# 1              Aqar Online  https://www.olx.com.eg/en/ads/user/7BNZC/
# 2             Golden Point  https://www.olx.com.eg/en/ads/user/77Bmq/
# 3                   Domova  https://www.olx.com.eg/en/ads/user/8byu7/
# 4                Investory  https://www.olx.com.eg/en/ads/user/7ynos/
# ...                    ...                                        ...
# 172256           New point  https://www.olx.com.eg/en/ads/user/84OHt/
# 172257     هانى عبد الفتاح  https://www.olx.com.eg/en/ads/user/7xNS4/
# 172258  Property Hills One  https://www.olx.com.eg/en/ads/user/7CIyu/
# 172259  Property Hills One  https://www.olx.com.eg/en/ads/user/7CIyu/
# 172260          فاطمه عمرو  https://www.olx.com.eg/en/ads/user/8biXr/
#
#                                    id
# 0                      /-IDcCqPt.html
# 1                /96-260-IDcDbEi.html
# 2                    /60-IDcD8xh.html
# 3                   /160-IDcCDF1.html
# 4                   /125-IDcCubX.html
# ...                               ...
# 172256  /221-10-the-icon-IDcuaET.html
# 172257                 /-IDct5Vc.html
# 172258                 /-IDct5Qn.html
# 172259             /10-7-IDcsV4B.html
# 172260                /3-IDcsJF3.html
#
# [172261 rows x 21 columns]

# %%
df.drop_duplicates('id', inplace=True)

# %%
plt.figure(figsize=(10,10))
sns.kdeplot(data=df, x='price', fill=True, log_scale=True)
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
df
# Out:
#           price                       location  \
# 0       1250000               Nasr City، Cairo
# 1       1260000                Madinaty, Cairo
# 2       1260000  New Cairo - El Tagamoa، Cairo
# 3       1250000        New Capital City، Cairo
# 4       1250000  New Cairo - El Tagamoa، Cairo
# ...         ...                            ...
# 172248  2438000        New Capital City, Cairo
# 172249  2437000        New Capital City, Cairo
# 172256  2436525  New Cairo - El Tagamoa، Cairo
# 172258  2437500  New Cairo - El Tagamoa، Cairo
# 172260  2433000        New Capital City, Cairo
#
#                                                     title bedrooms    area  \
# 0                       شقه ١٥٤م بعمارات العبور صلاح سالم        3     154
# 1                 شقه للبيع 96م فيو وايد جاردن بمليون 260        2      96
# 2       شقتك في قلب التجمع الخامس في بيت الوطن دقيقة م...        3     175
# 3                  شقة 160م بكومباوند بيرلا سموحة الجديدة        3     160
# 4           شقه للبيع 125م بالنرجس عمارات الترا سوبر لوكس        2     125
# ...                                                   ...      ...     ...
# 172248  بڤيو مميز ع النهر الاخضر امتلك شقه ف اجمل مواق...        3     187
# 172249  شقه 166م 3غرف+غرفة خدم بكمبوند Vinci باقساط مت...        3     166
# 172256  شقه للبيع 221م بتقسيط علي 10سنين في زا ايكون_T...        4     221
# 172258  استلم فووورا اخرر شقة بميدتاون امام الجامعة ال...        4     250
# 172260                          العاصمه الاداريه ديجويا 3        3  16,800
#
#          level bathrooms furnished       type  delivery_date  ...  \
# 0            3         2       NaN  Apartment            NaN  ...
# 1            5         2       NaN  Apartment  Ready to move  ...
# 2            2         2       NaN  Apartment            NaN  ...
# 3            3         2       NaN  Apartment            NaN  ...
# 4            2         1        No  Apartment  Ready to move  ...
# ...        ...       ...       ...        ...            ...  ...
# 172248  Ground         2        No  Apartment           2023  ...
# 172249       4         3       NaN  Apartment            NaN  ...
# 172256       1         3       NaN  Apartment            NaN  ...
# 172258  Ground         3        No  Apartment            NaN  ...
# 172260       5         2        No  Apartment           2023  ...
#
#        down_payment       payment_option   compound  delivery_term views  \
# 0               NaN                  NaN        NaN            NaN   522
# 1               NaN                 Cash        NaN       Finished   177
# 2               NaN          Installment        NaN  Semi Finished   105
# 3               NaN                 Cash        NaN            NaN   101
# 4               NaN                 Cash        NaN            NaN   424
# ...             ...                  ...        ...            ...   ...
# 172248      243,800  Cash or Installment  Diplomats  Semi Finished   148
# 172249          NaN                  NaN        NaN            NaN   146
# 172256      487,307  Cash or Installment        NaN            NaN   213
# 172258          NaN  Cash or Installment        NaN            NaN   385
# 172260      243,300          Installment    De Joya  Semi Finished   155
#
#                                               description        date  \
# 0       شقة ١٥٤ م بحري عمارات العبور علي صلاح سالم- تش...  01/02/2022
# 1       شقه للبيع 96م فيو وايد جاردن\nبالمرحله الحاديه...  08/02/2022
# 2       بيتك الجديد في قلب التجمع الخامس في بيت الوطن ...  07/02/2022
# 3       شقة بكومباوند بيرلا ١ سموحة الجديدة امام المدا...  03/02/2022
# 4       شقه بالنرجس عمارات 125م \nالترا سوبر لوكس دور ...  02/02/2022
# ...                                                   ...         ...
# 172248  امتلك شقتك في ابراج سكنيه متكامله الخدمات رائع...  14/12/2021
# 172249  موقع ومساحة المشروع العاصمة الإدارية\r\n(R7 G4...  12/12/2021
# 172256  شقه للبيع 221م  بتقسيط علي 10سنين في زا ايكون ...  28/11/2021
# 172258  استلم فووورا شقتك امام الجامعه الامريكيه مباشر...  20/11/2021
# 172260  DEJOYA 3 انتهز الفرصه موقع متميز ومساحه متميزه...  17/11/2021
#
#                 owner_name                                   owner_id  \
# 0                     wael  https://www.olx.com.eg/en/ads/user/6T42Q/
# 1              Aqar Online  https://www.olx.com.eg/en/ads/user/7BNZC/
# 2             Golden Point  https://www.olx.com.eg/en/ads/user/77Bmq/
# 3                   Domova  https://www.olx.com.eg/en/ads/user/8byu7/
# 4                Investory  https://www.olx.com.eg/en/ads/user/7ynos/
# ...                    ...                                        ...
# 172248  Property Hills One  https://www.olx.com.eg/en/ads/user/7CIyu/
# 172249          Amr Seleem  https://www.olx.com.eg/en/ads/user/86Nrx/
# 172256           New point  https://www.olx.com.eg/en/ads/user/84OHt/
# 172258  Property Hills One  https://www.olx.com.eg/en/ads/user/7CIyu/
# 172260          فاطمه عمرو  https://www.olx.com.eg/en/ads/user/8biXr/
#
#                                    id
# 0                      /-IDcCqPt.html
# 1                /96-260-IDcDbEi.html
# 2                    /60-IDcD8xh.html
# 3                   /160-IDcCDF1.html
# 4                   /125-IDcCubX.html
# ...                               ...
# 172248                 /-IDcvka4.html
# 172249    /166-3-vinci-9-IDcwYOD.html
# 172256  /221-10-the-icon-IDcuaET.html
# 172258                 /-IDct5Qn.html
# 172260                /3-IDcsJF3.html
#
# [98475 rows x 21 columns]

# %%
df.shape
# Out:
# (98475, 21)

# %%
df = df[df['price'] > 100000]

# %%
df.columns
# Out:
# Index(['price', 'location', 'title', 'bedrooms', 'area', 'level', 'bathrooms',
#        'furnished', 'type', 'delivery_date', 'amenties', 'down_payment',
#        'payment_option', 'compound', 'delivery_term', 'views', 'description',
#        'date', 'owner_name', 'owner_id', 'id'],
#       dtype='object')

# %%
cols = ['owner_name', 'owner_id', 'views']
df.drop(columns=cols, axis=1, inplace=True)

# %%
df.to_csv('real-state.csv', index=False)
