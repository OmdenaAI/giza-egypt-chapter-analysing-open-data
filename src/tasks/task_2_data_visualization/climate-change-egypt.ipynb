# %% [markdown]
# # Climate Change Indicators - Egypt

# %%
#importing libraries
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

import plotly.express as px

# %%
df = pd.read_csv('climate-change_egy.csv')
df = df.iloc[1: , :]
df
# Out:
#           Country Name Country ISO3  Year                   Indicator Name  \
# 1     Egypt, Arab Rep.          EGY  2018       Agricultural land (sq. km)
# 2     Egypt, Arab Rep.          EGY  2017       Agricultural land (sq. km)
# 3     Egypt, Arab Rep.          EGY  2016       Agricultural land (sq. km)
# 4     Egypt, Arab Rep.          EGY  2015       Agricultural land (sq. km)
# 5     Egypt, Arab Rep.          EGY  2014       Agricultural land (sq. km)
# ...                ...          ...   ...                              ...
# 1971  Egypt, Arab Rep.          EGY  1994  Roads, paved (% of total roads)
# 1972  Egypt, Arab Rep.          EGY  1993  Roads, paved (% of total roads)
# 1973  Egypt, Arab Rep.          EGY  1992  Roads, paved (% of total roads)
# 1974  Egypt, Arab Rep.          EGY  1991  Roads, paved (% of total roads)
# 1975  Egypt, Arab Rep.          EGY  1990  Roads, paved (% of total roads)
#
#       Indicator Code      Value
# 1     AG.LND.AGRI.K2  38359.688
# ...

# %%
df.shape
# Out:
# (1975, 6)

# %% [markdown]
# 1976 rows; 6 colums

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1975 entries, 1 to 1975
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    1975 non-null   object
#  1   Country ISO3    1975 non-null   object
#  2   Year            1975 non-null   object
#  3   Indicator Name  1975 non-null   object
#  4   Indicator Code  1975 non-null   object
#  5   Value           1975 non-null   object
# dtypes: object(6)
# memory usage: 92.7+ KB

# %%
df['Value'] = df['Value'].astype(float)
df['Year'] = df['Year'].astype(int)
df
# Out:
#           Country Name Country ISO3  Year                   Indicator Name  \
# 1     Egypt, Arab Rep.          EGY  2018       Agricultural land (sq. km)
# 2     Egypt, Arab Rep.          EGY  2017       Agricultural land (sq. km)
# 3     Egypt, Arab Rep.          EGY  2016       Agricultural land (sq. km)
# 4     Egypt, Arab Rep.          EGY  2015       Agricultural land (sq. km)
# 5     Egypt, Arab Rep.          EGY  2014       Agricultural land (sq. km)
# ...                ...          ...   ...                              ...
# 1971  Egypt, Arab Rep.          EGY  1994  Roads, paved (% of total roads)
# 1972  Egypt, Arab Rep.          EGY  1993  Roads, paved (% of total roads)
# 1973  Egypt, Arab Rep.          EGY  1992  Roads, paved (% of total roads)
# 1974  Egypt, Arab Rep.          EGY  1991  Roads, paved (% of total roads)
# 1975  Egypt, Arab Rep.          EGY  1990  Roads, paved (% of total roads)
#
#       Indicator Code      Value
# 1     AG.LND.AGRI.K2  38359.688
# ...

# %%
df.describe()
# Out:
#               Year         Value
# count  1975.000000  1.975000e+03
# mean   1992.617722  2.581626e+06
# std      16.177310  1.163196e+07
# min    1960.000000 -1.562833e+04
# 25%    1979.000000  2.579236e+00
# 50%    1994.000000  3.727373e+01
# 75%    2006.000000  7.206450e+03
# max    2020.000000  1.023344e+08

# %%
df.isnull().sum()
# Out:
# Country Name      0
# Country ISO3      0
# Year              0
# Indicator Name    0
# Indicator Code    0
# Value             0
# dtype: int64

# %% [markdown]
# No missing values

# %%
df['Indicator Name'].value_counts()
# Out:
# Urban population                                                                              61
# Agriculture, forestry, and fishing, value added (% of GDP)                                    61
# Urban population (% of total population)                                                      61
# Population, total                                                                             61
# Population in urban agglomerations of more than 1 million (% of total population)             61
#                                                                                               ..
# Urban population living in areas where elevation is below 5 meters (% of total population)     3
# Marine protected areas (% of territorial waters)                                               3
# GHG net emissions/removals by LUCF (Mt of CO2 equivalent)                                      1
# Droughts, floods, extreme temperatures (% of population, average 1990-2009)                    1
# ...

# %% [markdown]
# ### Land

# %%
temp = df[df['Indicator Name'] == 'Agricultural land (sq. km)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)


# Agriculture land (sq. km)


#sns.lineplot(data=temp, x='Year', y='Value').set(title='Agricultural land( sq. km)')
p= sns.relplot(data=temp, x='Year', y='Value', kind='line', height=5, aspect=2)
p.set(title='Agricultural land (sq. km)')

fig = px.line(temp, x="Year", y="Value", title='Agricultural land (sq. km)' , width=900, height=500)

fig.show()

# %%
temp = df[df['Indicator Name'] == 'Arable land (% of land area)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Agriculture land (sq. km)


p= sns.relplot(data=temp, x='Year', y='Value', kind='line', height=5, aspect=2)
p.set(title='Arable land (% of land area)')

fig = px.line(temp, x="Year", y="Value", title='Arable land (% of land area)' , width=900, height=500)

fig.show()

# %%
temp = df[df['Indicator Name'] == 'Forest area (sq. km)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))
plt.figure(figsize=(25,8))
sns.barplot(data=temp, x='Year', y='Value',)

fig = px.bar(temp, x="Year", y="Value", title='Forest area (sq. km)' , width=900, height=500)

fig.show()

# %% [markdown]
# #### Summary
#
# - Agricultural land: 25.68k (1961) | 38.3k (2018)
#
# - Arable land(% of land area):  2.59% (1961) | 2.92% (2018)
#
# - Forest area:  438 sq. km (1990) | 449.8 sq. km (2020) | Gradually increased from 1990 to 2010 (656 sq. km) then decreased to 449.88 sq. km

# %% [markdown]
# ### Power

# %%
temp = df[df['Indicator Name'] == 'Access to electricity (% of population)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))

p= sns.relplot(data=temp, x='Year', y='Value', kind='line', height=5, aspect=2)
p.set(title='Access to electricity (% of population)')

# %%
temp = df[df['Indicator Name'] == 'Renewable energy consumption (% of total final energy consumption)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))


p= sns.relplot(data=temp, x='Year', y='Value', kind='line', height=5, aspect=2)
p.set(title='Renewable energy consumption (% of total final energy consumption)')

# %%
temp = df[df['Indicator Name'] == 'CO2 emissions from gaseous fuel consumption (kt)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))
#plt.figure(figsize=(15,8))
#sns.lineplot(data=temp, x='Year', y='Value')

p= sns.relplot(data=temp, x='Year', y='Value', kind='line', height=5, aspect=2)
p.set(title='CO2 emissions from gaseous fuel consumption (kt)')

fig = px.line(temp, x="Year", y="Value", title='CO2 emissions from gaseous fuel consumption (kt)' , width=900, height=500)
fig.show()

# %%
temp = df[df['Indicator Name'] == 'CO2 emissions (kt)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))
plt.figure(figsize=(15,8))
sns.lineplot(data=temp, x='Year', y='Value').set(title='CO2 emissions (kt)')


fig = px.line(temp, x="Year", y="Value", title='CO2 emissions (kt)' , width=900, height=500)
fig.show()

# %%
temp = df[df['Indicator Name'] == 'CO2 emissions from liquid fuel consumption (kt)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))
plt.figure(figsize=(15,8))
sns.lineplot(data=temp, x='Year', y='Value').set(title='CO2 emissions from liquid fuel consumption (kt)')

fig = px.line(temp, x="Year", y="Value", title='CO2 emissions from liquid fuel consumption (kt)', width=900, height=500)
fig.show()

# %%
temp = df[df['Indicator Name'] == 'CO2 emissions (metric tons per capita)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))
plt.figure(figsize=(15,8))
sns.lineplot(data=temp, x='Year', y='Value').set(title='CO2 emissions (metric tons per capita)')

fig = px.line(temp, x="Year", y="Value", title='CO2 emissions (metric tons per capita)' , width=900, height=500)
fig.show()

# %%
temp = df[df['Indicator Name'] == 'CO2 emissions from solid fuel consumption (kt)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))
plt.figure(figsize=(15,8))
sns.lineplot(data=temp, x='Year', y='Value').set(title='CO2 emissions from solid fuel consumption (kt)')

fig = px.line(temp, x="Year", y="Value", title='CO2 emissions from solid fuel consumption (kt)' , width=900, height=500)
fig.show()

# %%
temp = df[df['Indicator Name'] == 'Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))
plt.figure(figsize=(15,8))
sns.lineplot(data=temp, x='Year', y='Value')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Value'>

# %%
temp = df[df['Indicator Name'] == 'Other greenhouse gas emissions (% change from 1990)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))
plt.figure(figsize=(15,8))
sns.lineplot(data=temp, x='Year', y='Value')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Value'>

# %%
temp = df[df['Indicator Name'] == 'Total greenhouse gas emissions (kt of CO2 equivalent)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))
plt.figure(figsize=(15,8))
sns.lineplot(data=temp, x='Year', y='Value').set(title='Total greenhouse gas emissions (kt of CO2 equivalent)')

fig = px.line(temp, x="Year", y="Value", title='Total greenhouse gas emissions (kt of CO2 equivalent)' , width=900, height=500)
fig.show()

# %%
temp = df[df['Indicator Name'] == 'Methane emissions (kt of CO2 equivalent)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))
plt.figure(figsize=(15,8))
sns.lineplot(data=temp, x='Year', y='Value').set(title='Methane emissions (kt of CO2 equivalent)')


fig = px.line(temp, x="Year", y="Value", title='Methane emissions (kt of CO2 equivalent)' , width=900, height=500)
fig.show()

# %%
temp = df[df['Indicator Name'] == 'Nitrous oxide emissions (thousand metric tons of CO2 equivalent)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))
plt.figure(figsize=(15,8))
sns.lineplot(data=temp, x='Year', y='Value').set(title='Nitrous oxide emissions (thousand metric tons of CO2 equivalent)')

fig = px.line(temp, x="Year", y="Value", title='Nitrous oxide emissions (thousand metric tons of CO2 equivalent)' , width=900, height=500)
fig.show()

# %%
temp = df[df['Indicator Name'] == 'PFC gas emissions (thousand metric tons of CO2 equivalent)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))
plt.figure(figsize=(15,8))
sns.barplot(data=temp, x='Year', y='Value').set(title='PFC gas emissions (thousand metric tons of CO2 equivalent)')

fig = px.bar(temp, x="Year", y="Value", title='PFC gas emissions (thousand metric tons of CO2 equivalent)' , width=900, height=500)
fig.show()

# %%
temp = df[df['Indicator Name'] == 'SF6 gas emissions (thousand metric tons of CO2 equivalent)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)



# Forest area (sq. km))
plt.figure(figsize=(15,8))
sns.barplot(data=temp, x='Year', y='Value').set(title='SF6 gas emissions (thousand metric tons of CO2 equivalent)')

fig = px.bar(temp, x="Year", y="Value", title='SF6 gas emissions (thousand metric tons of CO2 equivalent)' , width=900, height=500)
fig.show()

# %% [markdown]
# ### Summary
#
# - Co2 emissions(kt): 16k (1961) | 246.2k (2020)
#     - CO2 emissions from gaseous fuel consumption (kt): 99 (1964) | 94.9k (2016)
#     - CO2 emissions from liquid fuel consumption (kt): 14.6k (1960) | 114.8k (2016)
#     - CO2 emissions from solid fuel consumption (kt): 414 (1960) | 1353 (2016)
#
#
# - Greenhouse gas emissions: 56.8k (1970) | 329.2k (2018)
#
# - Methane emissions: 20.7k (1970) | 56.8k (2018)
#
# - Nitrous Oxide emissions: 7.8k (1970) | 22.3k (2018)

# %% [markdown]
# ## Natural Resources

# %%
temp = df[df['Indicator Name'] == 'Annual freshwater withdrawals, total (billion cubic meters)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))
plt.figure(figsize=(15,8))
sns.lineplot(data=temp, x='Year', y='Value').set(title='Annual freshwater withdrawals, total (billion cubic meters)')


fig = px.line(temp, x="Year", y="Value", title='Annual freshwater withdrawals, total (billion cubic meters)' , width=900, height=500)
fig.show()

# %%
temp = df[df['Indicator Name'] == 'Agriculture, forestry, and fishing, value added (% of GDP)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))
plt.figure(figsize=(15,8))
sns.lineplot(data=temp, x='Year', y='Value').set(title='Annual freshwater withdrawals, total (billion cubic meters)')

fig = px.line(temp, x="Year", y="Value", title='Annual freshwater withdrawals, total (billion cubic meters)' , width=900, height=500)
fig.show()

# %% [markdown]
# ### People

# %%
temp = df[df['Indicator Name'] == 'Mortality rate, under-5 (per 1,000 live births)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))
plt.figure(figsize=(15,8))
sns.lineplot(data=temp, x='Year', y='Value').set(title='Mortality rate, under-5 (per 1,000 live births)')


fig = px.line(temp, x="Year", y="Value", title='Mortality rate, under-5 (per 1,000 live births)' , width=900, height=500)
fig.show()

# %%
temp = df[df['Indicator Name'] == 'Population, total']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))
plt.figure(figsize=(15,8))
sns.lineplot(data=temp, x='Year', y='Value').set(title='Population, total')

fig = px.line(temp, x="Year", y="Value", title='Population, total' , width=900, height=500)
fig.show()

# %%
temp = df[df['Indicator Name'] == 'Population growth (annual %)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))
plt.figure(figsize=(15,8))
sns.lineplot(data=temp, x='Year', y='Value').set(title='Population growth (annual %)')

fig = px.line(temp, x="Year", y="Value", title='Population growth (annual %)' , width=900, height=500)
fig.show()

# %%
temp = df[df['Indicator Name'] == 'Urban population growth (annual %)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))
plt.figure(figsize=(15,8))
sns.lineplot(data=temp, x='Year', y='Value').set(title='Urban population growth (annual %)')

fig = px.line(temp, x="Year", y="Value", title='Urban population growth (annual %)' , width=900, height=500)
fig.show()

# %%
temp = df[df['Indicator Name'] == 'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)']
temp = temp.sort_values(by=['Year'], )
temp = temp.reset_index(drop=True)

temp

# Forest area (sq. km))
plt.figure(figsize=(15,8))
sns.barplot(data=temp, x='Year', y='Value').set(title='Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)')

fig = px.bar(temp, x="Year", y="Value", title='Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)' , width=900, height=500)
fig.show()
