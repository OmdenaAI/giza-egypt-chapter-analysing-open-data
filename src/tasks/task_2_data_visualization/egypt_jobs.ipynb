# %%
#import the useful libraries.
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.set_option('display.max_column', 50)  # to dislay all the columns 
pd.set_option('display.max_row', 100)

# %%
# Read the data set of "HCV" in data.
data= pd.read_csv("Wuzzuf_Jobs.csv")

# Printing the data
data
# Out:
#                                                Title  \
# 0                             Customer Service Agent
# 1                                  Marketing Manager
# 2                  Medical Representative Heliopolis
# 3                          Order Handling Specialist
# 4                                        Storekeeper
# ...                                              ...
# 4375      Corporate Sales Executive - Hotel Supplies
# 4376     Logistics Operations & Warehouse Supervisor
# 4377  English Teacher ( Second Language ) / Lower...
# 4378                         Project Manager - Cairo
# 4379                English Teacher / Primary Stages
#
#                                    Company     Location       Type  \
# 0                         Johnson Controls    New Cairo  Full Time
# 1                    SYE English Community        Dokki  Full Time
# 2                          So Value Pharma        Cairo  Full Time
# ...

# %%
display(list(data.columns.values)) # this step is of importance while it show you how to select an element.For example for Age if you 
                                    #  put 'Age' in place of 'Age ' => we can fix this by directly editing the csv file
# Out:
# ['Title',
#  'Company',
#  'Location',
#  'Type',
#  'Level',
#  'YearsExp',
#  'Country',
#  'Skills']

# %%
print(data.columns.tolist())
# Out:
# ['Title', 'Company', 'Location', 'Type', 'Level', 'YearsExp', 'Country', 'Skills']

# %%
# delete useless spaces from data header 
data.columns = data.columns.str.strip()
data.columns.tolist()
# Out:
# ['Title',
#  'Company',
#  'Location',
#  'Type',
#  'Level',
#  'YearsExp',
#  'Country',
#  'Skills']

# %% [markdown]
# Exploratory Data Analysis

# %% [markdown]
# ### Main goals : coorelation between variables

# %% [markdown]
# - Understand our data as well as possible (a small step forward is better than a big step back)
# - Develop a first modeling strategy

# %% [markdown]
# Check Data : Form analysis

# %%
data.head()
# Out:
#                                Title                Company    Location  \
# 0             Customer Service Agent       Johnson Controls   New Cairo
# 1                  Marketing Manager  SYE English Community       Dokki
# 2  Medical Representative Heliopolis        So Value Pharma       Cairo
# 3          Order Handling Specialist       Johnson Controls   New Cairo
# 4                        Storekeeper           Confidential       Cairo
#
#         Type        Level         YearsExp Country  \
# 0  Full Time  Entry Level   1-3 Yrs of Exp   Cairo
# 1  Full Time      Manager  5-10 Yrs of Exp    Giza
# 2  Full Time  Entry Level   0-5 Yrs of Exp   Egypt
# 3  Full Time  Experienced   3-5 Yrs of Exp   Cairo
# 4  Full Time  Experienced    3+ Yrs of Exp   Egypt
#
#                                               Skills
# 0  Call Center, Customer Support, Customer Care, ...
# 1  Market Research, Social Media, Online Marketin...
# 2  Cardio-metabolic, Sales Skills, Sales Target, ...
# ...

# %%
## Variables type
data.dtypes
# Out:
# Title       object
# Company     object
# Location    object
# Type        object
# Level       object
# YearsExp    object
# Country     object
# Skills      object
# dtype: object

# %%
df = data.copy()
df.shape
# Out:
# (4380, 8)

# %%
df.dtypes.value_counts()
# Out:
# object    8
# dtype: int64

# %%
plt.figure(figsize=[15,10])
first_20_jobs = df.Title.value_counts().head(20).index
count = df.Title.value_counts().head(20)

plt.barh(first_20_jobs, count)

plt.title('Top 20 Jobs Needed in Egypt')
plt.xticks(fontsize= 11)
plt.yticks(fontsize= 12)
plt.xlabel(' Requested time /Job')
# Out:
# Text(0.5, 0, ' Requested time /Job')

# %%
plt.figure(figsize=[15,10])
top_companies = df.Company.value_counts().head(20).index
count = df.Company.value_counts().head(20)

plt.barh(top_companies, count)

plt.title('Top 20 companies Egypt 2020', fontsize= 15)
plt.xticks(fontsize= 11)
plt.yticks(fontsize= 12)
plt.xlabel(' Requested times / company', fontsize=12);

# %%
plt.figure(figsize=[15,10])
Years_Exp = df.YearsExp.value_counts().head(20).index
count = df.YearsExp.value_counts().head(20)

plt.barh(Years_Exp, count)

plt.title('Experience', fontsize= 15)
plt.xticks(fontsize= 11)
plt.yticks(fontsize= 12)
plt.xlabel('number of jobs needed such exeperience level', fontsize=12);
